# %%
import pandas as pd

# %%
book_transactions = pd.read_csv("bookstore_transactions.csv")

# %%
book_transactions.head(2)
# Out:
#         Transaction
# 0  History,Bookmark
# 1  History,Bookmark

# %%
book_transactions.shape
# Out:
# (99, 1)

# %%
transactions = book_transactions["Transaction"].apply(lambda t: t.split(","))
type(transactions)
# Out:
# pandas.core.series.Series

# %%
list_transactions = list(transactions)
list_transactions[1]
# Out:
# ['History', 'Bookmark']
